# %%
# %matplotlib inline
import seaborn as sns

# Download the data, save to a file called "housing.data"
import urllib
data_url = "https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data"
urllib.urlretrieve (data_url, "housing.data")

# %%
names = ["CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE",
         "DIS", "RAD", "TAX", "PTRATIO", "B", "LSTAT", "MEDV"]

# %%
import pandas as pd

data = pd.read_csv("housing.data", header=None, names=names, delim_whitespace=True)

# Take a look at the first few rows
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
data['CRIM'].count()
# Out:
# 506

# %%
data.tail(5)
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9

# %%
data.plot.scatter(x='CRIM',y='MEDV')

# %%
from matplotlib import pyplot as plt

# %%
# Plot using matplotlib
plt.scatter(data["CRIM"], data["MEDV"])
plt.xlabel("Crime")
plt.ylabel("House Value")

# %%
plt.scatter(data["ZN"], data["MEDV"])
plt.xlabel("Lots over 25,000 sq ft")
plt.ylabel("House Value")
#Condos in all values and property larger higher values but still diverse

# %%
#seaborn
sns.regplot(x='ZN',y='MEDV', data = data);

# %%
plt.scatter(data["INDUS"], data["MEDV"])
plt.xlabel("Proportion non-retail per acre")
plt.ylabel("House Value")
#housing values are higher with less retail per acre

# %%
#seaborn
sns.regplot(x='INDUS',y='MEDV', data = data);

# %%
plt.scatter(data["CHAS"], data["MEDV"])
plt.xlabel("dummy variable 1 = bound to Charles")
plt.ylabel("House Value")
#less homes bound to charles but no low price homes

# %%
#seaborn
sns.regplot(x='CHAS',y='MEDV', data = data);

# %%
plt.scatter(data["NOX"], data["MEDV"])
plt.xlabel("Nitric Oxides concentrations")
plt.ylabel("House Value")
#Wealthy people don't live in high areas

# %%
#seaborn
sns.regplot(x='NOX',y='MEDV', data = data);

# %%
plt.scatter(data["RM"], data["MEDV"])
plt.xlabel("AVERAGE NUMBER OF ROOMS PER DWELLING")
plt.ylabel("House Value")

# %%
sns.regplot(x='RM',y='MEDV', data = data);
#AVERAGE NUMBER OF ROOMS PER DWELLING

# %%
plt.scatter(data["AGE"], data["MEDV"])
plt.xlabel("owner occupied built after 1940")
plt.ylabel("House Value")
#if percent owner occupied = 100 very scattered for value
#% this doesn't make sense

# %%
#seaborn
sns.regplot(x='AGE',y='MEDV', data = data);

# %%
plt.scatter(data["DIS"], data["MEDV"])
plt.xlabel("weighted distance to 5 boston employment centers")
plt.ylabel("House Value")
#closer to employment lower price homes

# %%
#seaborn
sns.regplot(x='DIS',y='MEDV', data = data);

# %%
plt.scatter(data["RAD"], data["MEDV"])
plt.xlabel("index access to radial highway")
plt.ylabel("House Value")
#diverse homes close to highway and lower home value further from

# %%
#seaborn
sns.regplot(x='RAD',y='MEDV', data = data);

# %%
plt.scatter(data["TAX"], data["MEDV"])
plt.xlabel("full-value property tax rate")
plt.ylabel("House Value")
#scattered

# %%
#seaborn
sns.regplot(x='TAX',y='MEDV', data = data);

# %%
plt.scatter(data["PTRATIO"], data["MEDV"])
plt.xlabel("pupil teacher ratio")
plt.ylabel("House Value")
#high pupil teacher lower house values

# %%
#seaborn
sns.regplot(x='PTRATIO',y='MEDV', data = data);

# %%
plt.scatter(data["B"], data["MEDV"])
plt.xlabel("Proportion of blacks")
plt.ylabel("House Value")
# higher proportion blacks scattered

# %%
#seaborn
sns.regplot(x='B',y='MEDV', data = data);

# %%
plt.scatter(data["LSTAT"], data["MEDV"])
plt.xlabel("%lower status of population")
plt.ylabel("House Value")
#finally a relationship the lower the status of population the lower the hourse value

# %%
#seaborn
sns.regplot(x='LSTAT',y='MEDV', data = data);

# %%
#CRIME TO LOWER STATUS OF POPULATION
sns.regplot(x='CRIM',y='LSTAT', data = data);

# %%
sns.regplot(x='DIS',y='AGE', data = data);
#SUBURBS WERE built further out

# %%
sns.set()
sns.pairplot(data, vars=['CRIM','ZN', 'INDUS','CHAS','NOX','RM','AGE',
                        'DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV'])
