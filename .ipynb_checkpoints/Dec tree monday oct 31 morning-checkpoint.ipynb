# %%
import pandas as pd
data=pd.read_csv('/Users/marthataylor/Downloads/used_cars.csv')

# %%
data
# Out:
#     price  year   miles  doors   type
# 0   22000  2012   13000      2    car
# 1   14000  2010   30000      2    car
# 2   13000  2010   73500      4    car
# 3    9500  2009   78000      4    car
# 4    9000  2007   47000      4    car
# 5    4000  2006  124000      2    car
# 6    3000  2004  177000      4    car
# 7    2000  2004  209000      4  truck
# 8    3000  2003  138000      2    car
# 9    1900  2003  160000      4    car
# 10   2500  2003  190000      2  truck
# 11   5000  2001   62000      4    car
# 12   1800  1999  163000      2  truck
# 13   1300  1997  138000      4    car

# %%
data['price'].describe()
# Out:
# count       14.000000
# mean      6571.428571
# std       6161.097376
# min       1300.000000
# 25%       2125.000000
# 50%       3500.000000
# 75%       9375.000000
# max      22000.000000
# Name: price, dtype: float64

# %%
data['year'].describe()
# Out:
# count      14.000000
# mean     2004.857143
# std         4.382784
# min      1997.000000
# 25%      2003.000000
# 50%      2004.000000
# 75%      2008.500000
# max      2012.000000
# Name: year, dtype: float64

# %%
data['miles'].describe()
# Out:
# count        14.000000
# mean     114464.285714
# std       63198.242516
# min       13000.000000
# 25%       64875.000000
# 50%      131000.000000
# 75%      162250.000000
# max      209000.000000
# Name: miles, dtype: float64

# %%
print data['doors'].describe()
print data['doors'].value_counts()
# Out:
# count    14.000000
# mean      3.142857
# std       1.027105
# min       2.000000
# 25%       2.000000
# 50%       4.000000
# 75%       4.000000
# max       4.000000
# Name: doors, dtype: float64
# 4    8
# 2    6
# Name: doors, dtype: int64

# %%
data['type'].describe()
# Out:
# count      14
# unique      2
# top       car
# freq       11
# Name: type, dtype: object

# %%
data['is_car']=data['type'].apply(lambda x: 1 if x=='car'else 0)

# %%
y=data['price']

# %%
x=data[['year' ,'miles', 'doors', 'is_car']]

# %%
from sklearn.cross_validation import train_test_split

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,
                                                 random_state=42, test_size=0.30)

# %%
print x_train.shape
print x_test.shape
print y_train.shape
print y_test.shape
# Out:
# (9, 4)
# (5, 4)
# (9,)
# (5,)

# %%
from sklearn.tree import DecisionTreeRegressor
decision_tree=DecisionTreeRegressor()

# %%
#fit training set
decision_tree.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#            splitter='best')

# %%
decision_tree.predict(x_train)
# Out:
# array([  3000.,  13000.,  14000.,   1300.,   9000.,   2000.,   2500.,
#          9500.,   3000.])

# %%
y_train
#perfect model
# Out:
# 8      3000
# 2     13000
# 1     14000
# 13     1300
# 4      9000
# 7      2000
# 10     2500
# 3      9500
# 6      3000
# Name: price, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(y_train, decision_tree.predict(x_train))

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_train,decision_tree.predict(x_train) )
# Out:
# 1.0

# %%
y_test
# Out:
# 9      1900
# 11     5000
# 0     22000
# 12     1800
# 5      4000
# Name: price, dtype: int64

# %%
decision_tree.predict(x_test)
# Out:
# array([  3000.,   3000.,  14000.,   1300.,   9000.])

# %%
def make_pretty_plots(y_true, y_pred):
    plt.scatter(y_true, y_pred)
    plt.plot(y_true, y_true)
    plt.ylim(0,25000)
    plt.xlim(0,25000)
    plt.show()

# %%
#how deep tree should go by using cv
import numpy as np
def find_mse(y_true, y_pred):
    values=[]
    for value in zip(y_true, y_pred):   #put into tuples first value with first vlaue
        values.append((value[0]-value[1])**2)
    return np.mean(values)

find_mse(y_test, decision_tree.predict(x_test))
# Out:
# 18892000.0

# %%
list_of_mse=[]
for x in range(1,11):
    new_decision_tree=DecisionTreeRegressor(max_depth =x)
    new_decision_tree.fit(x_train, y_train)
    predictions=new_decision_tree.predict(x_test)
    make_pretty_plots(y_test, predictions)
    mse=find_mse(y_test, predictions)
    list_of_mse.append(mse)
    
#depth is how many splits

# %%
list_of_mse
# Out:
# [31349210.0,
#  18595750.0,
#  19942000.0,
#  16492000.0,
#  18892000.0,
#  18892000.0,
#  16492000.0,
#  16492000.0,
#  16492000.0,
#  16492000.0]

# %%
plt.scatter(range(1,11),list_of_mse)

# %%
#best to leave at 4 my numbers are different but his shows 4 the same as other
#ones

# %%
decision_tree.feature_importances_
#being close to 1 is good
#look to the order that you added the variables
#what features contibuted
# Out:
# array([  9.94103188e-01,   5.27609494e-03,   6.20717052e-04,
#          0.00000000e+00])

# %%
#conda install pydot graphviz

# %%
#tree is from what we did at the beginning
feature_names = ['year', 'miles', 'doors', 'is_car']

from IPython.display import Image
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO
import pydot
dot_data = StringIO()  
export_graphviz(decision_tree, out_file=dot_data,  
                feature_names=feature_names,  
                filled=True, rounded=True,  
                special_characters=True)  
graph = pydot.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %%
#brew install libtool

# %%
from sklearn.grid_search import GridSearchCV
parms ={'max_depth': [1,2,3,4],
       'max_features':[1,2,3,4],
    'max_leaf_notes': [2,3,5]}

# %%
grid_search=GridSearchCV(estimator=DecisionTreeRegressor(),
                        parm_grid=par=)
decision_function=DecisionTreeRegressor(),
