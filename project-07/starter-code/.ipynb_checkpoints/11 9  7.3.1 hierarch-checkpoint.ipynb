# %%
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import sklearn as sk 
from sklearn.datasets import load_iris
import os
iris =load_iris()
data=iris['data']
data[0:5]
# Out:
# array([[ 5.1,  3.5,  1.4,  0.2],
#        [ 4.9,  3. ,  1.4,  0.2],
#        [ 4.7,  3.2,  1.3,  0.2],
#        [ 4.6,  3.1,  1.5,  0.2],
#        [ 5. ,  3.6,  1.4,  0.2]])

# %%
from scipy.cluster.hierarchy import linkage

# %%
hClusters = linkage(data, 'ward')
#algorthm how close points are to each other

# %%
Z
# Out:
# array([[  9.00000000e+00,   3.40000000e+01,   0.00000000e+00,
#           2.00000000e+00],
#        [  3.70000000e+01,   1.50000000e+02,   0.00000000e+00,
#           3.00000000e+00],
#        [  1.01000000e+02,   1.42000000e+02,   0.00000000e+00,
#           2.00000000e+00],
#        [  7.00000000e+00,   3.90000000e+01,   1.00000000e-01,
#           2.00000000e+00],
#        [  0.00000000e+00,   1.70000000e+01,   1.00000000e-01,
#           2.00000000e+00],
#        [  1.28000000e+02,   1.32000000e+02,   1.00000000e-01,
#           2.00000000e+00],
#        [  1.00000000e+01,   4.80000000e+01,   1.00000000e-01,
#           2.00000000e+00],
#        [  1.90000000e+01,   2.10000000e+01,   1.41421356e-01,
#           2.00000000e+00],
#        [  2.90000000e+01,   3.00000000e+01,   1.41421356e-01,
#           2.00000000e+00],
#        [  5.70000000e+01,   9.30000000e+01,   1.41421356e-01,
#           2.00000000e+00],
#        [  8.00000000e+01,   8.10000000e+01,   1.41421356e-01,
# ...

# %%
pwd
# Out:
# u'/Users/marthataylor/week03_classwork/project-07/starter-code'

# %%
#week-07/3.1-k-means-and-hierarchy/assets/

# %%
from scipy.cluster.hierarchy import cophenet
from scipy.spatial.distance import pdist
#c, coph_dists = cophenet(Z, pdist(X))

# %%
pdist(data)
# Out:
# array([ 0.53851648,  0.50990195,  0.64807407, ...,  0.6164414 ,
#         0.64031242,  0.76811457])

# %%
c, coph_dists = cophenet(hClusters, pdist(data))

# %%
c
# Out:
# 0.87260152506447042

# %%
coph_dists.shape
# Out:
# (11175,)

# %%
pdist(data).shape
# Out:
# (11175,)

# %%
from scipy.cluster.hierarchy import dendrogram, linkage, cophenet, fcluster
from scipy.spatial.distance import pdist

# %%
data.shape
# Out:
# (150, 4)

# %%
plt.figure(figsize=(20,16))

plt.title('Dendrogram')
plt.xlabel('Index Numbers')
plt.ylabel('Distance')
dendrogram(
    hClusters,
    leaf_rotation=90.,  
    leaf_font_size=8.,
)
plt.ylim(0,2)

plt.show()

# %%
hClusters[0:5]
# Out:
# array([[  9.00000000e+00,   3.40000000e+01,   0.00000000e+00,
#           2.00000000e+00],
#        [  3.70000000e+01,   1.50000000e+02,   0.00000000e+00,
#           3.00000000e+00],
#        [  1.01000000e+02,   1.42000000e+02,   0.00000000e+00,
#           2.00000000e+00],
#        [  7.00000000e+00,   3.90000000e+01,   1.00000000e-01,
#           2.00000000e+00],
#        [  0.00000000e+00,   1.70000000e+01,   1.00000000e-01,
#           2.00000000e+00]])

# %%
from scipy.cluster.hierarchy import fcluster

max_dist = 3
clusters = fcluster(hClusters, max_dist, criterion='distance')
clusters.shape
#id each to a cluster
# Out:
# (150,)

# %%
set(clusters)
#takea dict and give unique values
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
plt.scatter(data[:,0], data[:,2], c=clusters, cmap='viridis')
plt.show()

# %%
from scipy.cluster.hierarchy import fcluster

max_dist = 10
clusters = fcluster(hClusters, max_dist, criterion='distance')
clusters.shape
#id each to a cluster
# Out:
# (150,)

# %%
set(clusters)
# Out:
# {1, 2, 3}

# %%
plt.scatter(data[:,0], data[:,2], c=clusters, cmap='viridis')
plt.show()

# %%
import pandas as pd

# %%
wines = pd.read_csv('/Users/marthataylor/Downloads/wine.csv')

# %%
wines.head(
)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
quality = wines['quality']
wines.drop('quality', axis=1, inplace=True)

# %%
quality.shape
# Out:
# (1599,)

# %%
from sklearn.preprocessing import StandardScaler
wines_standardize=StandardScaler().fit_transform(wines.values)

# %%
wines_standardize.shape
# Out:
# (1599, 11)

# %%
# Out:
# (1599, 11)

# %%
wine_clusters=linkage(wines_standardize, 'ward')

# %%
wine_clusters[0]
# Out:
# array([ 0.,  4.,  0.,  2.])

# %%
c, coph_dists = cophenet(wine_clusters, pdist(wines_standardize))

# %%
c
#didnt do as a good as job clustering
# Out:
# 0.38577404147427347

# %%
plt.figure(figsize=(20,16))

plt.title('Dendrogram for wine')
plt.xlabel('Index Numbers')
plt.ylabel('Distance')
dendrogram(
    wine_clusters,
    leaf_rotation=90.,  
    leaf_font_size=8.,
)
#plt.ylim(0,2)

plt.show()

# %%
quality.value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
max_dist = 39
clusters = fcluster(wine_clusters, max_dist, criterion='distance')
clusters.shape
set(clusters)
#id each to a cluster
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
wines.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %%
import seaborn as sns

# %%
sns.pairplot(wines)

# %%
plt.scatter(wines['alcohol'], wines['pH'], c=clusters, cmap='viridis')
plt.title('6 clusters using hierarchical clustering')
plt.show()

# %%
plt.scatter(wines['alcohol'], wines['pH'], c=quality, cmap='viridis')
plt.title('6 clusters using hierarchical clustering')
plt.show()
#quality is all over the place 
#if you want to predict use another model like knn or regression
#this is for clustering 
#does it mean another put wines to put similar together

# %%
wines.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol
# 0      9.4
# 1      9.8
# 2      9.8
# 3      9.8
# 4      9.4

# %%
clusters
# Out:
# array([6, 6, 6, ..., 4, 4, 3], dtype=int32)

# %%
wines=wines.join(pd.DataFrame(clusters, columns=['clusters']))

# %%
wines.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  clusters
# 0      9.4         6
# 1      9.8         6
# ...

# %%
wines.groupby('clusters')['alcohol'].mean()
# Out:
# clusters
# 1     9.406061
# 2    10.425333
# 3    11.197248
# 4    10.078625
# 5    12.199158
# 6     9.991384
# Name: alcohol, dtype: float64

# %%
wines.groupby('clusters')['pH'].mean()
# Out:
# clusters
# 1    3.109091
# 2    3.098640
# 3    3.274067
# 4    3.293155
# 5    3.554646
# 6    3.367604
# Name: pH, dtype: float64
