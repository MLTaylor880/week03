# %%
#review
#need to learn classes

# %%
#different between standardization = scaling 
#regularization transforms and takes away

# %%
#  https://pokeapi.co/
#RESTful representatin something transfer

# %%
import requests as r
import json

# %%
BASE_URL='http://pokeapi.co/api/v2/'

# %%
#this goes into a script
def get_pokeman_data(pokenumber):
    request_url=BASE_URL + 'pokemon/%s'%pokenumber
    pokedata=r.get(request_url)
    return pokedata.json()

def get_gender_data(pokenumber):
    request_url=BASE_URL + 'gender/%s'%pokenumber
    gender_data=r.get(request_url)
    return gender_data.json()
    

with open ('bulbasaur_gender.txt', 'w')as outfile:
    json.dump(get_pokeman_data(1), outfile)

# %%
print get_pokeman_data(1)
# Out:
# {u'is_default': True, u'abilities': [{u'slot': 3, u'is_hidden': True, u'ability': {u'url': u'http://pokeapi.co/api/v2/ability/34/', u'name': u'chlorophyll'}}, {u'slot': 1, u'is_hidden': False, u'ability': {u'url': u'http://pokeapi.co/api/v2/ability/65/', u'name': u'overgrow'}}], u'stats': [{u'stat': {u'url': u'http://pokeapi.co/api/v2/stat/6/', u'name': u'speed'}, u'effort': 0, u'base_stat': 45}, {u'stat': {u'url': u'http://pokeapi.co/api/v2/stat/5/', u'name': u'special-defense'}, u'effort': 0, u'base_stat': 65}, {u'stat': {u'url': u'http://pokeapi.co/api/v2/stat/4/', u'name': u'special-attack'}, u'effort': 1, u'base_stat': 65}, {u'stat': {u'url': u'http://pokeapi.co/api/v2/stat/3/', u'name': u'defense'}, u'effort': 0, u'base_stat': 49}, {u'stat': {u'url': u'http://pokeapi.co/api/v2/stat/2/', u'name': u'attack'}, u'effort': 0, u'base_stat': 49}, {u'stat': {u'url': u'http://pokeapi.co/api/v2/stat/1/', u'name': u'hp'}, u'effort': 0, u'base_stat': 45}], u'name': u'bulbasaur', u'weight':
# ...

# %%
import os

# %%
pwd
# Out:
# u'/Users/marthataylor/GA/week03_classwork'

# %%
#create a script and then call it up in cli
#parser
with open('bulbasaur.txt', 'r') as infile:
    json_data=json.load(infile)
#print json_data

def extract_base(json_blob, json_key):
    return json_blob[json_key]

def stats_list(list_of_data):
    return[(item['stat']['name'],item['base_stat']) for item in list_of_data]
    for item in list_of_data:
        print item['stat']['name'],item['base_stat']
        
def types_list(list_of_data):
    return [(item['slot'],item['type']['name']) for item in list_of_data]
#     for item in list_of_data:
#         print item


def rate_parse(number):
    if item['rate']==-1:
           return -1
    else:
           return item['rate']/float(8)
    
    
def get_pokenumter(url):
    print url.split(url)
    

    
def all_pokeman_gender(list_of_data):
    dats_dictionary={}
    for item in list_of_data:
        rate=rate_parse(item['rate'])
        pokeman_name=item['pokemon_species']['name']
  
        
base_experience = extract_base(json_data, 'base_experience')
height = extract_base(json_data, 'height')
weight = extract_base(json_data, 'weight')

print ' base experience is %s' %base_experience
print ' height is %s' %height
print ' weight is %s' %weight

base_stats = stats_list(extract_base(json_data,'stats'))

for item in base_stats:
    print 'b %s starts %s' %(item[0], item[1])
#if no base experince key is will bomb
for item in types_list(extract_base(json_data, 'types')):
    print 'type is %s %s' %(item[0], item[1])
    
print gender_data['id']
print gender_data['name']
# Out:
#  base experience is 64
#  height is 7
#  weight is 69
# b speed starts 45
# b special-defense starts 65
# b special-attack starts 65
# b defense starts 49
# b attack starts 49
# b hp starts 45
# type is 2 poison
# type is 1 grass
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-ee145d911259> in <module>()
#      47     print 'type is %s %s' %(item[0], item[1])
#      48
# ---> 49 print gender_data['id']
#      50 print gender_data['name']
#
# NameError: name 'gender_data' is not defined

# %%
print json_data.keys()
print json_data['base_experience']
# Out:
# [u'forms', u'abilities', u'stats', u'name', u'held_items', u'order', u'sprites', u'location_area_encounters', u'weight', u'height', u'is_default', u'species', u'id', u'moves', u'game_indices', u'base_experience', u'types']
# 64
