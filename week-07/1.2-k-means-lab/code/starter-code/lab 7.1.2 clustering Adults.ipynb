# %% [markdown]
# **Section I: Import the Data**

# %% [markdown]
# Imports and Read in File

# %%
# %matplotlib inline 

import pandas as pd
import numpy as np
from sklearn import cluster
from sklearn import metrics
from sklearn.metrics import pairwise_distances
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')

# %%
adult = pd.read_csv("../../assets/datasets/adult.csv")

# %%
adult.tail(25)
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 48817   23           Private   93977       HS-grad              9
# 48818   73      Self-emp-inc  159691  Some-college             10
# 48819   35           Private  176967  Some-college             10
# 48820   66           Private  344436       HS-grad              9
# 48821   27           Private  430340  Some-college             10
# 48822   40           Private  202168   Prof-school             15
# 48823   51           Private   82720       HS-grad              9
# 48824   22           Private  269623  Some-college             10
# 48825   64  Self-emp-not-inc  136405       HS-grad              9
# 48826   50         Local-gov  139347       Masters             14
# 48827   55           Private  224655       HS-grad              9
# 48828   38           Private  247547     Assoc-voc             11
# 48829   58           Private  292710    Assoc-acdm             12
# ...

# %%
adult[adult["education"] == "Preschool"].squeeze()
# Out:
#        age         workclass  fnlwgt  education  education-num  \
# 224     53         Local-gov  140359  Preschool              1
# 932     51         Local-gov  241843  Preschool              1
# 2884    71           Private  235079  Preschool              1
# 2946    31           Private  452405  Preschool              1
# 3446    33           Private  239781  Preschool              1
# 3592    39               NaN  362685  Preschool              1
# 4107    52           Private  416129  Preschool              1
# 6433    27           Private  211032  Preschool              1
# 6864    54           Private  286989  Preschool              1
# 7070    30           Private  193598  Preschool              1
# 7173    64               NaN  140237  Preschool              1
# 7894    26           Private  322614  Preschool              1
# 8080    21           Private  243368  Preschool              1
# 8088    54               NaN  148657  Preschool              1
# ...

# %% [markdown]
# **Section II: Format the Data**

# %% [markdown]
# Convert the data to a Pandas dataframe to work with the data:

# %%
df = adult[['occupation','workclass','education','capital-gain', 'sex']].copy()
df.head()
# Out:
#           occupation         workclass  education  capital-gain     sex
# 0       Adm-clerical         State-gov  Bachelors          2174    Male
# 1    Exec-managerial  Self-emp-not-inc  Bachelors             0    Male
# 2  Handlers-cleaners           Private    HS-grad             0    Male
# 3  Handlers-cleaners           Private       11th             0    Male
# 4     Prof-specialty           Private  Bachelors             0  Female

# %%
for column in df.columns:
    print column, df(column).isnull().any()
# Out:
# occupation
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-b2585f7782cd> in <module>()
#       1 for column in df.columns:
# ----> 2     print column, df(column).isnull().any()
#
# TypeError: 'DataFrame' object is not callable

# %%
df['occupation'].fillna('Missing Occupation',inplace=True)
df['occupation'].value_counts
# Out:
# <bound method Series.value_counts of 0              Adm-clerical
# 1           Exec-managerial
# 2         Handlers-cleaners
# 3         Handlers-cleaners
# 4            Prof-specialty
# 5           Exec-managerial
# 6             Other-service
# 7           Exec-managerial
# 8            Prof-specialty
# 9           Exec-managerial
# 10          Exec-managerial
# 11           Prof-specialty
# 12             Adm-clerical
# 13                    Sales
# 14             Craft-repair
# 15         Transport-moving
# 16          Farming-fishing
# 17        Machine-op-inspct
# 18                    Sales
# 19          Exec-managerial
# 20           Prof-specialty
# 21            Other-service
# 22          Farming-fishing
# 23         Transport-moving
# 24             Tech-support
# 25             Tech-support
# 26             Craft-repair
# 27       Missing Occupation
# 28          Exec-managerial
# 29             Craft-repair
#                 ...
# 48812    Missing Occupation
# ...

# %% [markdown]
# Convert the categorical Data to numeric for our analysis. **HINT:** Refer to lesson 1.1 for writing a function of this sort

# %% [markdown]
# Apply the functions you just wrote and append the results to the dataframe

# %% [markdown]
# **Section III: Examine the Data**

# %% [markdown]
# Plot the Data to see the distributions our our target markets; plot multiple indicators to see the relationships *IE: Education and Income*

# %% [markdown]
# **Section IV: Prepare for Clustering**

# %% [markdown]
# Create a New Dataframe with just numerical data for the analysis

# %% [markdown]
# Check for NaN and Infinite Numbers - Our data is messy!

# %%
np.any(np.isnan(...))

# %% [markdown]
# Convert to the Pandas Array to a Numpy Matrix - Your function will only take numerical inputs

# %% [markdown]
# **Section V: Clustering Analysis**

# %% [markdown]
# Cluster the Data to our our target groups. **BONUS**: Perform multiple clustering tests on various indicator variables

# %% [markdown]
# Get the labels and centroids

# %%
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

# %% [markdown]
# Compute the Silhoutte Score to measure your analysis

# %% [markdown]
# if you do not like the results then set it up

# %%
#sns.distplot(final_df_loc(final_df['three classes)'))) look at this to see a certain class

# %% [markdown]
# to see how many clusters
# you could just visualize it from a plotting but if you have lots of columns then the lots of pair plots
